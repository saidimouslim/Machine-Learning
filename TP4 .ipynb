# %% [markdown]
# # Classification

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from itertools import product
import matplotlib.image as img
import scipy.stats as ss
import seaborn as sns
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler,OneHotEncoder,OrdinalEncoder
from sklearn.linear_model import LogisticRegression,SGDClassifier
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.tree import export_text
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from joblib import dump, load
import os
from sklearn.model_selection import ShuffleSplit,cross_validate,LearningCurveDisplay,KFold
from sklearn.metrics import accuracy_score, precision_score, recall_score,f1_score,make_scorer,confusion_matrix,roc_curve,auc
import graphviz 

import io
from io import StringIO
import sys

# %% [markdown]
# ## Dataset Description

# %%
breast_cancer = pd.read_csv("breast-cancer_csv.csv")
breast_cancer
# Out:
#        age menopause tumor-size inv-nodes node-caps  deg-malig breast  \
# 0    40-49   premeno      15-19       0-2       yes          3  right
# 1    50-59      ge40      15-19       0-2        no          1  right
# 2    50-59      ge40      35-39       0-2        no          2   left
# 3    40-49   premeno      35-39       0-2       yes          3  right
# 4    40-49   premeno      30-34       3-5       yes          2   left
# ..     ...       ...        ...       ...       ...        ...    ...
# 281  50-59      ge40      30-34       6-8       yes          2   left
# 282  50-59   premeno      25-29       3-5       yes          2   left
# 283  30-39   premeno      30-34       6-8       yes          2  right
# 284  50-59   premeno      15-19       0-2        no          2  right
# 285  50-59      ge40      40-44       0-2        no          3   left
#
#     breast-quad irradiat                 Class
# 0       left_up       no     recurrence-events
# 1       central       no  no-recurrence-events
# 2      left_low       no     recurrence-events
# 3      left_low      yes  no-recurrence-events
# 4      right_up       no     recurrence-events
# ..          ...      ...                   ...
# 281    left_low       no  no-recurrence-events
# 282    left_low      yes  no-recurrence-events
# 283    right_up       no  no-recurrence-events
# 284    left_low       no  no-recurrence-events
# 285    right_up       no  no-recurrence-events
#
# [286 rows x 10 columns]

# %%
breast_cancer.columns
# Out:
# Index(['age', 'menopause', 'tumor-size', 'inv-nodes', 'node-caps', 'deg-malig',
#        'breast', 'breast-quad', 'irradiat', 'Class'],
#       dtype='object')

# %%
breast_cancer.describe()
# Out:
#         deg-malig
# count  286.000000
# mean     2.048951
# std      0.738217
# min      1.000000
# 25%      2.000000
# 50%      2.000000
# 75%      3.000000
# max      3.000000

# %%
breast_cancer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 286 entries, 0 to 285
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          286 non-null    object
#  1   menopause    286 non-null    object
#  2   tumor-size   286 non-null    object
#  3   inv-nodes    286 non-null    object
#  4   node-caps    278 non-null    object
#  5   deg-malig    286 non-null    int64
#  6   breast       286 non-null    object
#  7   breast-quad  285 non-null    object
#  8   irradiat     286 non-null    object
#  9   Class        286 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 22.5+ KB

# %%
breast_cancer.isna().sum()
# Out:
# age            0
# menopause      0
# tumor-size     0
# inv-nodes      0
# node-caps      8
# deg-malig      0
# breast         0
# breast-quad    1
# irradiat       0
# Class          0
# dtype: int64

# %% [markdown]
# ### Only one row contains Null value on the `breast-quad` column, we can drop it

# %%
breast_cancer.dropna(inplace=True)

# %%
breast_cancer.isna().sum()
# Out:
# age            0
# menopause      0
# tumor-size     0
# inv-nodes      0
# node-caps      0
# deg-malig      0
# breast         0
# breast-quad    0
# irradiat       0
# Class          0
# dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# 1. Plot the distribution of samples according to their classes. What do you observe?
# 2. Code from scratch a mixed version of naive Bayes.
# 3. Verify if the dataset respects some related hypothesis to the following ML algorithms (such as Gaussian distribution and independency between features for naive Bayes, Linear Separability for Logistic regression..
# ....)
# 4. Train the implemented mixed naive Bayes, SVM, KNN, Logistic regression, and Decision Tree (from
#     sklearn) on all the breast cancer dataset.
# 5. Plot the graph of convergence of Logistic regression.
# 6. Display, export, and import the generated models.
# 7. Evaluate the performance of the generated models using the 5-cross-validation evaluation method and
#     display the confusion matrix for each split. Display the mean of recall, precision, f1-score, and the ROC curves.
# 8. Which evaluation metric do you recommend using for this dataset: unbalanced and medical?
# 9. Import the best model according to the chosen metric and its pre-processings and predict the class of the third simple using the best model models.
#
#
#
# <div/>

# %% [markdown]
# ### 1- Plot the distribution of the samples according to their classes

# %%
breast_cancer['Class'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Class'>

# %% [markdown]
# we notice that the dataset is inbalanced,the recurrence events are minority.

# %% [markdown]
# ### 2-The mixed naive bayes implementation

# %%
class MixteNaiveBayes:
    
    def __init__(self, categorical):
        self.model = None
        self.categorical = categorical
        self.classes = None
        self.columns = None

    def get_params(self, deep=True):
        return {
            'categorical': self.categorical,
        }

    def set_params(self, **parameters):
        for parameter, value in parameters.items():
            setattr(self, parameter, value)
        return self
        
    def fit(self, X, Y):
        
        self.model = []
        self.classes, counts = np.unique(Y, return_counts = True)

        self.columns = X.columns if isinstance(X,pd.DataFrame) else np.arange(X.shape[1])
        
        for i in self.columns:

            if isinstance(X,pd.DataFrame):
                column = X[i]
            else:
                column =  X[:,i]
                        
            if i in self.categorical:
                p = self.__handle_categorical_attribute__(column, Y)
            else:
                p = self.__handle_numerical_attribute__(column, Y)
                
            self.model.append(p)
        
        probabilities = dict(zip(self.classes, counts / counts.sum()))
        self.model.append(probabilities)

        return self
        
            
    def predict(self, X):
        
        p = self.predict_proba(X)
        return self.classes[np.argmax(p, axis = 1)]
    
    def predict_proba(self, X):
        
        if self.model is None:
            raise Exception("fit was not called")
        
        y_hat = []
        n = X.shape[1]

        if isinstance(X,pd.DataFrame):
            X = X.iloc
                    
        for x in X:
            probailities = []
            for group in self.classes:
                p = 1
                for i in range(n):
                    if self.columns[i] in self.categorical:
                        key = x[i]
                        if key in self.model[i][group].keys():
                            p = p * self.model[i][group][x[i]]
                        # else:
                            # p = 0
                    else:
                        std = self.model[i][group]['std']
                        mean = self.model[i][group]['mean']
                        p = p * self.__gauss__(mean, std, x[i])
                p = p * self.model[-1][group]
                probailities.append(p)
            probailities = np.array(probailities)
            probailities = probailities / probailities.sum()
            y_hat.append(probailities)

        return np.array(y_hat)
        
    def __gauss__(self, mean, std, x):
        return np.exp(-0.5 * ((x - mean) / std) ** 2) / (np.sqrt(2 * np.pi) * std)
            
    def __handle_categorical_attribute__(self, column, Y):
        
        probabilities = {}
        values = np.unique(column)
        
        for group in self.classes:
            mask = Y == group
            _Y = Y[mask]
            _column = column[mask]
            probabilities[group] = {}
            for value in values:
                probabilities[group][value] = _Y[_column == value].shape[0] / _Y.shape[0]
                
        return probabilities
    
    def __handle_numerical_attribute__(self, column, Y):
        
        probabilities = {}
        
        for group in self.classes:
            
            _column = column[Y == group]
            
            mean = np.mean(_column)
            std = np.std(_column, ddof=1)
            
            probabilities[group] = {
                'mean': mean,
                'std': std
            }
            
        return probabilities

    def score(self, x, y, sample_weight=None):
        y_hat = self.predict(x)
        return np.mean(y_hat == y)

# %% [markdown]
# ### 3- Verify the hypothesis

# %% [markdown]
# #### Naive Bayes

# %% [markdown]
# 1. Gaussian distribution

# %%
breast_cancer.select_dtypes(include = np.number).plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# 2. features independance
#
# to test the correlation between the attriutes of this dataset we will use the chi square test since all the features are categorical, details are available at : [Correlation between Categorical Variables](https://medium.com/@ritesh.110587/correlation-between-categorical-variables-63f6bd9bf2f7#:~:text=Chi%2DSquare%20test%20of%20independence,categorical%20variables%20is%20easily%20available.)

# %%
def chi_square_test(dataset):

    n = dataset.columns.shape[0]
    results = [[0] * n for _ in range(n)]

    for i,col1 in enumerate(dataset.columns):
        for j,col2 in enumerate(dataset.columns):
            if i == j:
                results[i][j] = np.nan
            elif i > j:
                results[i][j] = results[j][i]
            else:
                crosstab = pd.crosstab(dataset[col1], dataset[col2])
                contingency = ss.chi2_contingency(crosstab)[1]
                results[i][j] = contingency
    return pd.DataFrame(data = results, index = dataset.columns, columns = dataset.columns)

# %%
chi_matrix = chi_square_test(breast_cancer)

# %%
plt.rcParams["figure.figsize"] = (16, 8)
sns.heatmap(data = chi_matrix, annot = True)
# Out:
# <Axes: >

# %% [markdown]
# the features with higher dependency

# %%
rows, columns = np.where(chi_matrix < 0.05)
mask = rows > columns
rows = rows[mask]
columns = columns[mask]
list(zip(breast_cancer.columns[rows], breast_cancer.columns[columns]))
# Out:
# [('menopause', 'age'),
#  ('node-caps', 'inv-nodes'),
#  ('deg-malig', 'tumor-size'),
#  ('deg-malig', 'inv-nodes'),
#  ('deg-malig', 'node-caps'),
#  ('breast-quad', 'tumor-size'),
#  ('breast-quad', 'breast'),
#  ('irradiat', 'inv-nodes'),
#  ('irradiat', 'node-caps'),
#  ('irradiat', 'deg-malig'),
#  ('Class', 'tumor-size'),
#  ('Class', 'inv-nodes'),
#  ('Class', 'node-caps'),
#  ('Class', 'deg-malig'),
#  ('Class', 'irradiat')]

# %% [markdown]
# #### Logestic regression

# %% [markdown]
# 1. Linear separibility

# %% [markdown]
# ### 4- Training

# %% [markdown]
# #### split the data

# %%
X, Y = breast_cancer[breast_cancer.columns[breast_cancer.columns != "Class"]], breast_cancer["Class"].map({
    'no-recurrence-events': 0,
    'recurrence-events': 1
})

# %% [markdown]
# #### preprocessing

# %%
ordinal_cols = ['age', 'tumor-size', 'inv-nodes','node-caps','deg-malig', 'breast', 'irradiat']
one_hot_cols = ['menopause', 'breast-quad']

# %%
categories_order = []

for col in ordinal_cols:

    cats = breast_cancer[col].value_counts().index.tolist()

    if len(cats) != 2: # the column is in form of intervals => sort the categories
        cats.sort(key=lambda x: float(x.split("-")[0]) if isinstance(x, str) else x)
    
    categories_order.append(cats)

# %%
categories_order
# Out:
# [['20-29', '30-39', '40-49', '50-59', '60-69', '70-79'],
#  ['0-4',
#   '5-9',
#   '10-14',
#   '15-19',
#   '20-24',
#   '25-29',
#   '30-34',
#   '35-39',
#   '40-44',
#   '45-49',
#   '50-54'],
#  ['0-2', '3-5', '6-8', '9-11', '12-14', '15-17', '24-26'],
#  ['no', 'yes'],
#  [1, 2, 3],
#  ['left', 'right'],
#  ['no', 'yes']]

# %%
ordinal_transformer = Pipeline(steps=[
    ('ordinal_encoder', OrdinalEncoder(categories=categories_order))
])

# %%
one_hot_transformer = Pipeline(steps=[
    ('one_hot_encoder', OneHotEncoder(handle_unknown='ignore'))
])

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('ordinal', ordinal_transformer, ordinal_cols),
        ('one_hot', one_hot_transformer, one_hot_cols)
    ]
)

# %%
pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('scaler', StandardScaler())
])

# %% [markdown]
# #### Logestic regression

# %%
def train(model, x, y):
    old_stdout = sys.stdout
    sys.stdout = mystdout = StringIO()
    model.fit(x,y)
    sys.stdout = old_stdout
    loss_history = mystdout.getvalue()
    loss_list = []
    for line in loss_history.split('\n'):
        if(len(line.split("loss: ")) == 1):
            continue
        loss_list.append(float(line.split("loss: ")[-1]))
    return np.array(loss_list)

# %% [markdown]
# - work with SGDCassifier class because it is based on gradient descent.

# %%
logistic_pipeline = Pipeline(steps=[
    ('preprocessing', pipeline),
    ('estimator', SGDClassifier(verbose = 1))
])

# %%
history = train(logistic_pipeline, X, Y)

# %%
logistic_pipeline.fit(X, Y)
# Out:
# -- Epoch 1
# Norm: 79.49, NNZs: 15, Bias: -31.762754, T: 277, Avg. loss: 22.221648
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 68.13, NNZs: 15, Bias: -47.700099, T: 554, Avg. loss: 21.327702
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 49.24, NNZs: 15, Bias: -40.215618, T: 831, Avg. loss: 17.492245
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 51.59, NNZs: 15, Bias: -34.029634, T: 1108, Avg. loss: 14.678508
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 60.76, NNZs: 15, Bias: -33.412575, T: 1385, Avg. loss: 12.461303
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 44.99, NNZs: 15, Bias: -32.982275, T: 1662, Avg. loss: 11.348784
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 38.12, NNZs: 15, Bias: -25.578331, T: 1939, Avg. loss: 9.696799
# Total training time: 0.00 seconds.
# -- Epoch 8
# Norm: 37.99, NNZs: 15, Bias: -12.876442, T: 2216, Avg. loss: 10.096843
# Total training time: 0.00 seconds.
# -- Epoch 9
# Norm: 39.54, NNZs: 15, Bias: -33.362496, T: 2493, Avg. loss: 6.800611
# Total training time: 0.00 seconds.
# -- Epoch 10
# Norm: 31.26, NNZs: 15, Bias: -13.829352, T: 2770, Avg. loss: 7.599756
# Total training time: 0.00 seconds.
# -- Epoch 11
# Norm: 27.98, NNZs: 15, Bias: -8.913731, T: 3047, Avg. loss: 8.218438
# Total training time: 0.00 seconds.
# -- Epoch 12
# Norm: 31.59, NNZs: 15, Bias: -14.145970, T: 3324, Avg. loss: 7.251637
# Total training time: 0.00 seconds.
# -- Epoch 13
# Norm: 24.13, NNZs: 15, Bias: -14.189976, T: 3601, Avg. loss: 6.675754
# Total training time: 0.00 seconds.
# -- Epoch 14
# Norm: 24.83, NNZs: 15, Bias: -7.946439, T: 3878, Avg. loss: 5.952793
# Total training time: 0.00 seconds.
# -- Epoch 15
# Norm: 22.72, NNZs: 15, Bias: -8.047208, T: 4155, Avg. loss: 6.495618
# Total training time: 0.00 seconds.
# -- Epoch 16
# Norm: 24.78, NNZs: 15, Bias: -15.653696, T: 4432, Avg. loss: 5.620160
# Total training time: 0.00 seconds.
# -- Epoch 17
# Norm: 19.59, NNZs: 15, Bias: -12.020086, T: 4709, Avg. loss: 5.965925
# Total training time: 0.00 seconds.
# -- Epoch 18
# Norm: 24.10, NNZs: 15, Bias: -3.633371, T: 4986, Avg. loss: 5.286797
# Total training time: 0.00 seconds.
# -- Epoch 19
# Norm: 21.35, NNZs: 15, Bias: -15.169420, T: 5263, Avg. loss: 5.014282
# Total training time: 0.00 seconds.
# -- Epoch 20
# Norm: 15.68, NNZs: 15, Bias: -10.348021, T: 5540, Avg. loss: 5.311044
# Total training time: 0.00 seconds.
# -- Epoch 21
# Norm: 18.00, NNZs: 15, Bias: -5.856373, T: 5817, Avg. loss: 4.669041
# Total training time: 0.00 seconds.
# -- Epoch 22
# Norm: 17.14, NNZs: 15, Bias: -11.617599, T: 6094, Avg. loss: 4.436226
# Total training time: 0.00 seconds.
# -- Epoch 23
# Norm: 17.50, NNZs: 15, Bias: -11.560338, T: 6371, Avg. loss: 4.466268
# Total training time: 0.00 seconds.
# -- Epoch 24
# Norm: 15.03, NNZs: 15, Bias: -11.465618, T: 6648, Avg. loss: 4.711585
# Total training time: 0.00 seconds.
# -- Epoch 25
# Norm: 16.31, NNZs: 15, Bias: -11.400381, T: 6925, Avg. loss: 3.642934
# Total training time: 0.00 seconds.
# -- Epoch 26
# Norm: 17.45, NNZs: 15, Bias: -5.224621, T: 7202, Avg. loss: 3.678327
# Total training time: 0.00 seconds.
# -- Epoch 27
# Norm: 15.63, NNZs: 15, Bias: -5.338920, T: 7479, Avg. loss: 3.772275
# Total training time: 0.00 seconds.
# -- Epoch 28
# Norm: 13.44, NNZs: 15, Bias: -5.420130, T: 7756, Avg. loss: 4.712454
# Total training time: 0.00 seconds.
# -- Epoch 29
# Norm: 12.45, NNZs: 15, Bias: -8.811023, T: 8033, Avg. loss: 3.256548
# Total training time: 0.00 seconds.
# -- Epoch 30
# Norm: 12.87, NNZs: 15, Bias: -8.750377, T: 8310, Avg. loss: 3.587411
# Total training time: 0.00 seconds.
# -- Epoch 31
# Norm: 12.79, NNZs: 15, Bias: -6.594222, T: 8587, Avg. loss: 3.264462
# Total training time: 0.00 seconds.
# -- Epoch 32
# Norm: 13.04, NNZs: 15, Bias: -7.613835, T: 8864, Avg. loss: 3.225727
# Total training time: 0.00 seconds.
# -- Epoch 33
# Norm: 11.43, NNZs: 15, Bias: -5.660884, T: 9141, Avg. loss: 3.238760
# Total training time: 0.00 seconds.
# -- Epoch 34
# Norm: 10.76, NNZs: 15, Bias: -6.621147, T: 9418, Avg. loss: 2.967452
# Total training time: 0.00 seconds.
# -- Epoch 35
# Norm: 10.96, NNZs: 15, Bias: -8.470552, T: 9695, Avg. loss: 3.348606
# Total training time: 0.00 seconds.
# -- Epoch 36
# Norm: 11.07, NNZs: 15, Bias: -5.661085, T: 9972, Avg. loss: 2.960837
# Total training time: 0.00 seconds.
# -- Epoch 37
# Norm: 11.53, NNZs: 15, Bias: -9.225353, T: 10249, Avg. loss: 2.982947
# Total training time: 0.00 seconds.
# -- Epoch 38
# Norm: 11.77, NNZs: 15, Bias: -7.424432, T: 10526, Avg. loss: 3.106404
# Total training time: 0.00 seconds.
# -- Epoch 39
# Norm: 10.78, NNZs: 15, Bias: -5.698145, T: 10803, Avg. loss: 2.787118
# Total training time: 0.00 seconds.
# -- Epoch 40
# Norm: 10.24, NNZs: 15, Bias: -6.535222, T: 11080, Avg. loss: 3.016320
# Total training time: 0.00 seconds.
# -- Epoch 41
# Norm: 13.54, NNZs: 15, Bias: -5.716372, T: 11357, Avg. loss: 2.789366
# Total training time: 0.00 seconds.
# -- Epoch 42
# Norm: 11.38, NNZs: 15, Bias: -2.569393, T: 11634, Avg. loss: 3.093267
# Total training time: 0.00 seconds.
# -- Epoch 43
# Norm: 10.40, NNZs: 15, Bias: -1.858726, T: 11911, Avg. loss: 2.640414
# Total training time: 0.00 seconds.
# -- Epoch 44
# Norm: 10.71, NNZs: 15, Bias: -4.939352, T: 12188, Avg. loss: 2.263689
# Total training time: 0.00 seconds.
# -- Epoch 45
# Norm: 8.18, NNZs: 15, Bias: -4.959077, T: 12465, Avg. loss: 2.560922
# Total training time: 0.00 seconds.
# -- Epoch 46
# Norm: 10.20, NNZs: 15, Bias: -3.491243, T: 12742, Avg. loss: 2.413956
# Total training time: 0.00 seconds.
# -- Epoch 47
# Norm: 10.06, NNZs: 15, Bias: -5.644041, T: 13019, Avg. loss: 2.411982
# Total training time: 0.00 seconds.
# -- Epoch 48
# Norm: 8.31, NNZs: 15, Bias: -6.323914, T: 13296, Avg. loss: 2.326756
# Total training time: 0.00 seconds.
# -- Epoch 49
# Norm: 8.92, NNZs: 15, Bias: -4.923726, T: 13573, Avg. loss: 2.516710
# Total training time: 0.00 seconds.
# Convergence after 49 epochs took 0.00 seconds
# Pipeline(steps=[('preprocessing',
#                  Pipeline(steps=[('preprocessor',
#                                   ColumnTransformer(transformers=[('ordinal',
#                                                                    Pipeline(steps=[('ordinal_encoder',
#                                                                                     OrdinalEncoder(categories=[['20-29',
#                                                                                                                 '30-39',
#                                                                                                                 '40-49',
#                                                                                                                 '50-59',
#                                                                                                                 '60-69',
#                                                                                                                 '70-79'],
#                                                                                                                ['0-4',
#                                                                                                                 '5-9',
#                                                                                                                 '10-14',
#                                                                                                                 '15-19',
#                                                                                                                 '20-24',
#                                                                                                                 '25-29',
#                                                                                                                 '30-34',
#                                                                                                                 '35-39',
#                                                                                                                 '40-44',
#                                                                                                                 '45-49',
#                                                                                                                 '50-54'],
#                                                                                                                ['0-2',
#                                                                                                                 '3-5',
#                                                                                                                 '6-8',
#                                                                                                                 '9-11',
#                                                                                                                 '12-14',
#                                                                                                                 '15-17',
#                                                                                                                 '24-26'],
#                                                                                                                ['no',
#                                                                                                                 'yes'],
#                                                                                                                [1,
#                                                                                                                 2,
#                                                                                                                 3],
#                                                                                                                ['left',
#                                                                                                                 'right'],
#                                                                                                                ['no',
#                                                                                                                 'yes']]))]),
#                                                                    ['age',
#                                                                     'tumor-size',
#                                                                     'inv-nodes',
#                                                                     'node-caps',
#                                                                     'deg-malig',
#                                                                     'breast',
#                                                                     'irradiat']),
#                                                                   ('one_hot',
#                                                                    Pipeline(steps=[('one_hot_encoder',
#                                                                                     OneHotEncoder(handle_unknown='ignore'))]),
#                                                                    ['menopause',
#                                                                     'breast-quad'])])),
#                                  ('scaler', StandardScaler())])),
#                 ('estimator', SGDClassifier(verbose=1))])

# %% [markdown]
# #### K-Nearset-Neighbors

# %%
knn_pipeline = Pipeline(steps=[
    ('preprocessing', pipeline),
    ('estimator', KNeighborsClassifier(n_neighbors = 7))
])

# %%
knn_pipeline.fit(X, Y)
# Out:
# Pipeline(steps=[('preprocessing',
#                  Pipeline(steps=[('preprocessor',
#                                   ColumnTransformer(transformers=[('ordinal',
#                                                                    Pipeline(steps=[('ordinal_encoder',
#                                                                                     OrdinalEncoder(categories=[['20-29',
#                                                                                                                 '30-39',
#                                                                                                                 '40-49',
#                                                                                                                 '50-59',
#                                                                                                                 '60-69',
#                                                                                                                 '70-79'],
#                                                                                                                ['0-4',
#                                                                                                                 '5-9',
#                                                                                                                 '10-14',
#                                                                                                                 '15-19',
#                                                                                                                 '20-24',
#                                                                                                                 '25-29',
#                                                                                                                 '30-34',
#                                                                                                                 '35-39',
#                                                                                                                 '40-44',
#                                                                                                                 '45-49',
#                                                                                                                 '50-54'],
#                                                                                                                ['0-2',
#                                                                                                                 '3-5',
#                                                                                                                 '6-8',
#                                                                                                                 '9-11',
#                                                                                                                 '12-14',
#                                                                                                                 '15-17',
#                                                                                                                 '24-26'],
#                                                                                                                ['no',
#                                                                                                                 'yes'],
#                                                                                                                [1,
#                                                                                                                 2,
#                                                                                                                 3],
#                                                                                                                ['left',
#                                                                                                                 'right'],
#                                                                                                                ['no',
#                                                                                                                 'yes']]))]),
#                                                                    ['age',
#                                                                     'tumor-size',
#                                                                     'inv-nodes',
#                                                                     'node-caps',
#                                                                     'deg-malig',
#                                                                     'breast',
#                                                                     'irradiat']),
#                                                                   ('one_hot',
#                                                                    Pipeline(steps=[('one_hot_encoder',
#                                                                                     OneHotEncoder(handle_unknown='ignore'))]),
#                                                                    ['menopause',
#                                                                     'breast-quad'])])),
#                                  ('scaler', StandardScaler())])),
#                 ('estimator', KNeighborsClassifier(n_neighbors=7))])

# %% [markdown]
# #### Mixte Naive Bayes

# %%
mnb_model = Pipeline(steps=[
    ('estimator',MixteNaiveBayes(categorical = breast_cancer.columns))
])

# %%
mnb_model.fit(X, Y)
# Out:
# Pipeline(steps=[('estimator',
#                  <__main__.MixteNaiveBayes object at 0x7fad6ba4f310>)])

# %% [markdown]
# #### Decision Tree

# %%
tree_pipeline = Pipeline(steps=[
    ('preprocessing', preprocessor),
    ('estimator', DecisionTreeClassifier())
])

# %%
tree_pipeline.fit(X, Y)
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('ordinal',
#                                                   Pipeline(steps=[('ordinal_encoder',
#                                                                    OrdinalEncoder(categories=[['20-29',
#                                                                                                '30-39',
#                                                                                                '40-49',
#                                                                                                '50-59',
#                                                                                                '60-69',
#                                                                                                '70-79'],
#                                                                                               ['0-4',
#                                                                                                '5-9',
#                                                                                                '10-14',
#                                                                                                '15-19',
#                                                                                                '20-24',
#                                                                                                '25-29',
#                                                                                                '30-34',
#                                                                                                '35-39',
#                                                                                                '40-44',
#                                                                                                '45-49',
#                                                                                                '50-54'],
#                                                                                               ['0-2',
#                                                                                                '3-5',
#                                                                                                '6-8',
#                                                                                                '9-11',
#                                                                                                '12-14',
#                                                                                                '15-17',
#                                                                                                '24-26'],
#                                                                                               ['no',
#                                                                                                'yes'],
#                                                                                               [1,
#                                                                                                2,
#                                                                                                3],
#                                                                                               ['left',
#                                                                                                'right'],
#                                                                                               ['no',
#                                                                                                'yes']]))]),
#                                                   ['age', 'tumor-size',
#                                                    'inv-nodes', 'node-caps',
#                                                    'deg-malig', 'breast',
#                                                    'irradiat']),
#                                                  ('one_hot',
#                                                   Pipeline(steps=[('one_hot_encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['menopause',
#                                                    'breast-quad'])])),
#                 ('estimator', DecisionTreeClassifier())])

# %% [markdown]
# #### SVM

# %%
svm_pipeline = Pipeline(steps=[
    ('preprocessing', preprocessor),
    ('estimator', SVC())
])
svm_pipeline.fit(X, Y)
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('ordinal',
#                                                   Pipeline(steps=[('ordinal_encoder',
#                                                                    OrdinalEncoder(categories=[['20-29',
#                                                                                                '30-39',
#                                                                                                '40-49',
#                                                                                                '50-59',
#                                                                                                '60-69',
#                                                                                                '70-79'],
#                                                                                               ['0-4',
#                                                                                                '5-9',
#                                                                                                '10-14',
#                                                                                                '15-19',
#                                                                                                '20-24',
#                                                                                                '25-29',
#                                                                                                '30-34',
#                                                                                                '35-39',
#                                                                                                '40-44',
#                                                                                                '45-49',
#                                                                                                '50-54'],
#                                                                                               ['0-2',
#                                                                                                '3-5',
#                                                                                                '6-8',
#                                                                                                '9-11',
#                                                                                                '12-14',
#                                                                                                '15-17',
#                                                                                                '24-26'],
#                                                                                               ['no',
#                                                                                                'yes'],
#                                                                                               [1,
#                                                                                                2,
#                                                                                                3],
#                                                                                               ['left',
#                                                                                                'right'],
#                                                                                               ['no',
#                                                                                                'yes']]))]),
#                                                   ['age', 'tumor-size',
#                                                    'inv-nodes', 'node-caps',
#                                                    'deg-malig', 'breast',
#                                                    'irradiat']),
#                                                  ('one_hot',
#                                                   Pipeline(steps=[('one_hot_encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['menopause',
#                                                    'breast-quad'])])),
#                 ('estimator', SVC())])

# %% [markdown]
# ### 5- Convergence graph for logestic regression

# %%
plt.rcParams['figure.figsize'] = [6, 5]

plt.title("Logistic Regression learning rate")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.plot(history)

# %% [markdown]
# ### 6- Display and Export the models

# %% [markdown]
# #### Display the models

# %% [markdown]
# 1. Logestic Regression

# %%
logistic_pipeline['estimator'].coef_
# Out:
# array([[-2.3317258 ,  0.70647356,  1.28908217,  1.6717063 ,  4.1649176 ,
#          0.32242093,  1.25414635, -0.60831392, -6.08497973,  2.23115149,
#          0.62708442,  0.24466457,  0.87902383,  0.42198588, -2.52373002]])

# %% [markdown]
# 2. Mixte Naive Bayes

# %%
dfs = []
index = []

for i,x in enumerate(mnb_model["estimator"].model[:-1]): 
    df = pd.DataFrame(x)
    dfs.append(df)
    index += [breast_cancer.columns[i]] * df.index.shape[0]

df = pd.concat(dfs)
df = df.set_index([index, df.index])

df
# Out:
#                               0         1
# age         20-29      0.005102  0.000000
#             30-39      0.107143  0.185185
#             40-49      0.316327  0.333333
#             50-59      0.352041  0.271605
#             60-69      0.193878  0.209877
#             70-79      0.025510  0.000000
# menopause   ge40       0.459184  0.407407
#             lt40       0.025510  0.000000
#             premeno    0.515306  0.592593
# tumor-size  0-4        0.035714  0.012346
#             10-14      0.137755  0.012346
#             15-19      0.117347  0.074074
#             20-24      0.173469  0.172840
#             25-29      0.168367  0.222222
#             30-34      0.168367  0.296296
#             35-39      0.061224  0.086420
#             40-44      0.081633  0.074074
#             45-49      0.010204  0.012346
#             5-9        0.020408  0.000000
#             50-54      0.025510  0.037037
# inv-nodes   0-2        0.846939  0.530864
#             12-14      0.005102  0.024691
#             15-17      0.015306  0.037037
#             24-26      0.000000  0.012346
#             3-5        0.086735  0.209877
#             6-8        0.035714  0.123457
#             9-11       0.010204  0.061728
# node-caps   no         0.872449  0.617284
#             yes        0.127551  0.382716
# deg-malig   1          0.290816  0.111111
#             2          0.515306  0.345679
#             3          0.193878  0.543210
# breast      left       0.510204  0.555556
#             right      0.489796  0.444444
# breast-quad central    0.086735  0.049383
#             left_low   0.372449  0.407407
#             left_up    0.352041  0.308642
#             right_low  0.086735  0.074074
#             right_up   0.102041  0.160494
# irradiat    no         0.836735  0.629630
#             yes        0.163265  0.370370

# %%
mnb_model["estimator"].model[-1]
# Out:
# {0: 0.7075812274368231, 1: 0.2924187725631769}

# %% [markdown]
# 3. Decision Tree

# %%
data = export_graphviz(tree_pipeline['estimator'])
graph = graphviz.Source(data, format="png") 
filename = graph.render("decision_tree_graphivz")

# %%
image = img.imread(filename)

plt.title("Decision Tree")
plt.imshow(image)
plt.show()

# %% [markdown]
# 4. Support Vector Machine

# %%
svm_pipeline["estimator"].class_weight_
# Out:
# array([1., 1.])

# %% [markdown]
# #### Export the models

# %%
dump(value = logistic_pipeline, filename = os.path.join('models', 'lr.joblib'))
dump(value = knn_pipeline, filename = os.path.join('models', 'knn.joblib'))
dump(value = mnb_model, filename = os.path.join('models', 'mnb.joblib'))
dump(value = tree_pipeline, filename = os.path.join('models', 'dtree.joblib'))
dump(value = svm_pipeline, filename = os.path.join('models', 'svm.joblib'))
# Out:
# ['models/svm.joblib']

# %% [markdown]
# #### Import the models

# %%
lr = load(filename = os.path.join('models', 'lr.joblib'))
knn = load(filename = os.path.join('models', 'knn.joblib'))
mnb = load(filename = os.path.join('models', 'mnb.joblib'))
dtree = load(filename = os.path.join('models', 'dtree.joblib'))
svm = load(filename = os.path.join('models', 'svm.joblib'))

# %% [markdown]
# ### 7- Performance evaluation

# %% [markdown]
# #### accuracy, precision, recall

# %%
def cm(score):
    def scorer(clf, X, y):
        y_pred = clf.predict(X)
        cm = confusion_matrix(y, y_pred)
        cm = {'tp': cm[0, 0], 'fp': cm[0, 1],
                'fn': cm[1, 0], 'tn': cm[1, 1]}

        return cm[score]
    return scorer

# %%
names = ['Logestic Regression', 'K-Nearset-Neighbors', 'Decision Tree', 'Support Vector Machine', 'Mixed Naive Bayes']
models = [lr, knn, dtree, svm, mnb]
series = []
scoring = {
    'accuracy': make_scorer(accuracy_score),
    'precision': make_scorer(precision_score),
    'recall': make_scorer(recall_score),
    'f1_score': make_scorer(f1_score),
    'tn': cm('tn'),
    'tp': cm('tp'),
    'fp': cm('fp'),
    'fn': cm('fn')
}

# %%
confusion_matrices = []
k = 5

for i,model in enumerate(models):
    results = cross_validate(model, X, Y, cv=KFold(n_splits=k,shuffle=True), scoring=scoring)
    serie = []
    cms = [[],[]]
    for key in results.keys():
        if key not in ['fit_time', 'score_time','test_tn','test_tp','test_fp','test_fn']:
            serie.append(results[key].mean())

    for i in range(k):
        cms[0].extend([results["test_tp"][i],results["test_fp"][i]])
        cms[1].extend([results["test_fn"][i],results["test_tn"][i]])
                
    confusion_matrices.append(cms[0])  
    confusion_matrices.append(cms[1])  
    series.append(pd.Series(serie, index = ["accuracy", "precision", "recall", "f1-score"]))
# Out:
# -- Epoch 1
# Norm: 96.81, NNZs: 15, Bias: -71.942127, T: 221, Avg. loss: 25.173439
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 71.04, NNZs: 15, Bias: -45.911107, T: 442, Avg. loss: 21.994630
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 66.84, NNZs: 15, Bias: -32.613878, T: 663, Avg. loss: 17.709506
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 63.10, NNZs: 15, Bias: -42.351195, T: 884, Avg. loss: 14.994022
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 47.01, NNZs: 15, Bias: -36.769681, T: 1105, Avg. loss: 14.044435
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 50.71, NNZs: 15, Bias: -19.327306, T: 1326, Avg. loss: 14.487300
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 49.35, NNZs: 15, Bias: -39.451588, T: 1547, Avg. loss: 10.846957
# Total training time: 0.00 seconds.
# -- Epoch 8
# Norm: 42.92, NNZs: 15, Bias: -24.316459, T: 1768, Avg. loss: 11.207891
# Total training time: 0.00 seconds.
# -- Epoch 9
# Norm: 39.06, NNZs: 15, Bias: -20.680164, T: 1989, Avg. loss: 11.279188
# Total training time: 0.00 seconds.
# -- Epoch 10
# Norm: 38.69, NNZs: 15, Bias: -23.420873, T: 2210, Avg. loss: 9.147891
# Total training time: 0.00 seconds.
# -- Epoch 11
# Norm: 28.90, NNZs: 15, Bias: -20.089456, T: 2431, Avg. loss: 8.669047
# Total training time: 0.00 seconds.
# -- Epoch 12
# Norm: 28.47, NNZs: 15, Bias: -25.434314, T: 2652, Avg. loss: 8.705484
# Total training time: 0.00 seconds.
# -- Epoch 13
# Norm: 33.16, NNZs: 15, Bias: -25.013755, T: 2873, Avg. loss: 7.929047
# Total training time: 0.00 seconds.
# -- Epoch 14
# Norm: 29.45, NNZs: 15, Bias: -10.148392, T: 3094, Avg. loss: 8.423178
# Total training time: 0.00 seconds.
# -- Epoch 15
# Norm: 30.42, NNZs: 15, Bias: -10.463037, T: 3315, Avg. loss: 6.454233
# Total training time: 0.00 seconds.
# -- Epoch 16
# Norm: 30.00, NNZs: 15, Bias: -8.399606, T: 3536, Avg. loss: 6.716317
# Total training time: 0.00 seconds.
# -- Epoch 17
# Norm: 27.10, NNZs: 15, Bias: -10.690707, T: 3757, Avg. loss: 6.559390
# Total training time: 0.00 seconds.
# -- Epoch 18
# Norm: 24.71, NNZs: 15, Bias: -16.869597, T: 3978, Avg. loss: 6.275438
# Total training time: 0.00 seconds.
# -- Epoch 19
# Norm: 21.71, NNZs: 15, Bias: -22.646405, T: 4199, Avg. loss: 6.366592
# Total training time: 0.00 seconds.
# -- Epoch 20
# Norm: 22.09, NNZs: 15, Bias: -16.848563, T: 4420, Avg. loss: 5.596471
# Total training time: 0.00 seconds.
# -- Epoch 21
# Norm: 24.46, NNZs: 15, Bias: -5.960778, T: 4641, Avg. loss: 5.383389
# Total training time: 0.00 seconds.
# -- Epoch 22
# Norm: 24.21, NNZs: 15, Bias: -11.235055, T: 4862, Avg. loss: 4.921434
# Total training time: 0.00 seconds.
# -- Epoch 23
# Norm: 22.40, NNZs: 15, Bias: -14.581012, T: 5083, Avg. loss: 5.158870
# Total training time: 0.00 seconds.
# -- Epoch 24
# Norm: 22.92, NNZs: 15, Bias: -6.578577, T: 5304, Avg. loss: 4.845017
# Total training time: 0.00 seconds.
# -- Epoch 25
# Norm:
# Total training time: 0.00 seconds.
# -- Epoch 34
# Norm: 12.82, NNZs: 15, Bias: -6.964009, T: 7548, Avg. loss: 4.153488
# Total training time: 0.00 seconds.
# Convergence after 34 epochs took 0.00 seconds

# %%
df = pd.DataFrame(data=series, index = names)
df
# Out:
#                         accuracy  precision    recall  f1-score
# Logestic Regression     0.592078   0.280351  0.257265  0.267182
# K-Nearset-Neighbors     0.714610   0.506111  0.272017  0.347854
# Decision Tree           0.602857   0.345401  0.366104  0.346667
# Support Vector Machine  0.736558   0.675000  0.210292  0.312355
# Mixed Naive Bayes       0.736494   0.560820  0.540686  0.536883

# %% [markdown]
# #### confusion matrices

# %%
index = np.array(list(product(names, ["P", "N"])))
columns = np.array(list(product([f"Fold {i}" for i in range(5)], ["P", "N"])))

# %%
pd.DataFrame(confusion_matrices, index=[index[:,0],index[:,1]], columns = [columns[:,0],columns[:,1]])
# Out:
#                          Fold 0     Fold 1    Fold 2     Fold 3     Fold 4
#                               P   N      P  N      P   N      P   N      P   N
# Logestic Regression    P     26  12     34  9     27  12     25  12     31   8
#                        N     15   3     10  3     12   4     11   7     12   4
# K-Nearset-Neighbors    P     35   4     37  4     28   7     38   3     38   2
#                        N     11   6     10  5     15   5      9   5     14   1
# Decision Tree          P     26   9     31  8     24  18     31  10     26  13
#                        N     15   6     12  5      8   5      8   6      9   7
# Support Vector Machine P     35   0     37  3     42   2     37   3     36   1
#                        N     17   4     11  5      9   2     12   3     15   3
# Mixed Naive Bayes      P     33   9     35  4     30   9     29   4     34   9
#                        N      7   7     10  7      6  10     11  11      4   8

# %% [markdown]
# #### ROC curves and auc scores

# %%
def is_probabilistic_model(model):
    has_predict_proba = getattr(model, 'predict_proba', None)
    has_probability = getattr(model, 'probability', None)
    return has_predict_proba and (has_probability is None or model.probability)

# %%
fig, axes = plt.subplots(nrows = 2,ncols = 2)

plt.rcParams["figure.figsize"] = (14,4)
i = 0

for j,model in enumerate(models):
    if is_probabilistic_model(model['estimator']):        
        y_hat = model.predict_proba(X)[:,1]
        fpr, tpr, thresholds = roc_curve(Y, y_hat)
        auc_score = auc(fpr, tpr)
        axe = axes[i // 2][i % 2]
    
        axe.plot(
            fpr,
            tpr,
            color="darkorange",
            lw=2,
            label="ROC curve (area = %0.2f)" % auc_score,
        )
        axe.plot([0, 1], [0, 1], color="navy", lw=2, linestyle="--")
        axe.set_xlim([0.0, 1.0])
        axe.set_ylim([0.0, 1.05])
        axe.set_xlabel("False Positive Rate")
        axe.set_ylabel("True Positive Rate")
        axe.set_title(f"ROC curve for : {names[j]}")
        axe.legend(loc="lower right")
        i += 1

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 8- Best metric

# %% [markdown]
# because the dataset is inablanced and medical so we would like to reduce the probability of predicting postive samples as negative, therfore the best metric to evaluate the models is : recall.

# %% [markdown]
# ### 9- Choosing the best model

# %% [markdown]
# according to metric chosen in the previous question the best model is : Naive Bayes.

# %%
mixed_naive_bayes = load(filename = os.path.join('models', 'mnb.joblib'))

# %%
mixed_naive_bayes.score(X, Y)
# Out:
# 0.7689530685920578

# %%
n = 2
y = Y[n]
y_hat = mixed_naive_bayes.predict(X.iloc[[n]])

print(f"predicted class = {y_hat[0]}, actual class = {y}")
# Out:
# predicted class = 0, actual class = 1
